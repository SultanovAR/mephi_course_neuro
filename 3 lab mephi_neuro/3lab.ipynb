# %%
import pandas as pd
import torch.nn as nn
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
#Настройки варианта...

_data_file_name = "data_lab3v0" + str(1) + ".csv"
_num_first = 10 #num_neuro_in_first_layer
_f_first = nn.Softplus #func_in_first_layer
_num_second = 10
_f_second = nn.Softplus
_learning_mod = "Batch"

# %%
data = pd.read_csv(_data_file_name, header=None, names=("x", "y", "class"))
data.head()
# Out:
#         x        y  class
# 0  1.6715  0.95858      1
# 1  1.1920  0.39126      1
# 2  1.6228  1.88600      1
# 3  3.4380  2.85800      1
# 4  2.7135  3.65780      1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
# x        500 non-null float64
# y        500 non-null float64
# class    500 non-null int64
# dtypes: float64(2), int64(1)
# memory usage: 11.8 KB

# %%
grouped_data = data.groupby(by="class")["x"].count()
grouped_data
# Out:
# class
# 1    100
# 2    150
# 3    150
# 4    100
# Name: x, dtype: int64

# %%
colors = ['orange','green','blue','purple']

fig = plt.figure(figsize=(16,9))
plt.scatter(data['x'], data['y'], c=data['class'], cmap=matplotlib.colors.ListedColormap(colors))
plt.title("1 - Orange, 2 - Green, 3 - Blue, 4 - Purple")
plt.savefig('img/classes.png', bbox_inches='tight')
